# %%
a = [1,2,3,[4,5,6],[1,2,3],7,8,9]
b =  a

a[3][0] = 0
a[4][1] = 0

print(a)
print(b)

# %%
Name = "Neharika"
Name1 = Name[1:]
new_name = "P" + Name1
print(new_name)
# Out:
# Peharika

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
