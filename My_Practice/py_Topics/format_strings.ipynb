# %%
name = 'Neharika'
age = 30

# format_string = "Hello i am {} and i am {} years old".format(name,age)
format_string = "Hello i am {0} and i am {1} years old".format(name,age)
format_string = "Hello i am {1} and i am {0} years old".format(name,age)

print(format_string)
print(type(format_string))
# Out:
# Hello i am 30 and i am Neharika years old
# <class 'str'>

# %%
str1 = f"hello {name} i am {age} years old"
print(str1)
print(type(str1))
# Out:
# hello Neharika i am 30 years old
# <class 'str'>
