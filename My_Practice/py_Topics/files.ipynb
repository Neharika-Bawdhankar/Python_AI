# %%
f = open("GFG.txt","w")
f.write("Hello World")
f.close()

# read the file
f = open("GFG.txt",'r')
print(f.read())
# Out:
# Hello World

# %%
try:
    with open("GFG.txt",'r') as file:
        content = file.read()
        print(content)
finally:
    file.close()
# Out:
# Hello World

# %%
with open ("sample.txt",'r+') as file:
    file_contents = file.read()
    print(file_contents)
    file.write("Reagrds, Neharika")
# Out:
# All the previous data is deleted This is all overwrtitten

# %%
with open("sample.txt", 'w+') as file1:
    content = file1.write("All the previous data is deleted This is all overwrtitten")
    print(content)
# Out:
# 57
