# %% [markdown]
# #Modules in python

# %%
import math
pi_value = math.pi
print(pi_value)
# Out:
# 3.141592653589793

# %%
import random
ran_number = random.randint(1,1000)

# %%
print(ran_number)
# Out:
# 313

# %%
sample = """ This is testing for comment section"""

# %%
print(sample)
# Out:
#  This is testing for comment section

# %%
sample1 = """ This is testing for comment section in "python" language"""
print(sample1)
# Out:
#  This is testing for comment section in "python" language

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name = "Neharika"
Name = "neharika"
print(name , id(name))
print(Name , id(Name))
# Out:
# Neharika 2738064130928
# neharika 2738064143920
