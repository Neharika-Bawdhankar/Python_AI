# %%
class person:          #base class
    def __init__(self,name):
        self.name = name

class Employee(person):      #inherts from parent class named person
    def __init__(self, name, salary):
        super().__init__(name)
        self.salary = salary

emp = Employee("John",20000)
print(emp.name, emp.salary)
# Out:
# John 20000

# %%
class Job:
    def __init__(self,title1):
        self.title = title1
        
class EmployeeJob(Employee, Job):
    def __init__(self, name, salary, title):
        Employee.__init__(self, name, salary)
        Job.__init__(self, job)
