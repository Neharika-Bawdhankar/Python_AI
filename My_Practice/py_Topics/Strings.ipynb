# %%
text = "NehariKA"
print(id(text))
# dir(text)
# Out:
# 2071442714480

# %%
# print(text)
text = "nehariKA"
text.capitalize()
print(id(text))
print(text)
# text1 = '123UNWANTED'
# text1.capitalize()
# Out:
# 2071442714864
# nehariKA

# %%
Str = 'STRAße'
print(id(Str))
Str.casefold()
Str.lower()
print(id(Str))
# Out:
# 2071442806192
# 2071442806192

# %%
text.center(25,'-')
# Out:
# '---------Neharika--------'

# %%
str2 = "Neharikkkaaaaaaaaa"
str2.count("a")
# Out:
# 10

# %%
s = "apple banana apple grape apple"             # indexing starts from zero here
substring = "apple"

# Using start and end parameters to count occurrences 
# of "apple" within a specific range
res = s.count(substring, 0, 20)  

print(res)
# Out:
# 2

# %%
a = "Python is fun!"
utf8_encoded = a.encode("utf-8")
print(utf8_encoded)
# Out:
# b'Python is fun!'

# %%
a = "Pythön"
encoded_ascii = a.encode("ascii", errors="replace")
print(encoded_ascii)
# Out:
# b'Pyth?n'

# %%
a = "Pythön"

encoded_backslash = a.encode("ascii", errors="backslashreplace")
print(encoded_backslash)
# Out:
# b'Pyth\\xf6n'

# %%
a = "Pythön"

encoded_xml = a.encode("ascii", errors="xmlcharrefreplace")
print(encoded_xml)
# Out:
# b'Pyth&#246;n'

# %%
text.endswith("A")
text.endswith("A",5,15)
# Out:
# True

# %%
text.endswith(('a','A','N'))      #so a tuple is used to check if it ends with a or A or N and if it has any one of them it will returm true else false
# Out:
# True

# %%
f = "Neharika.png"
if f.endswith(('jpg','jpeg','png')):
    print("file is valid")
else:
    print("Invalid file type!")
# Out:
# file is valid

# %%
s = "Python is fun!"
# Expanding tabs in a string without tabs
result = s.expandtabs(4)
print(result)
# Out:
# Python is fun!

# %%
s = "Python\tis\tfun"
# Expanding tabs with a custom size of 4 spaces
res = s.expandtabs(4)
print(res)
# Out:
# Python  is  fun

# %%
s = "A\tB\tC"
# Expanding tabs with default tab size
res = s.expandtabs()
print(res)
# Out:
# A       B       C

# %%
s = "Python is fun"
index = s.find("Python,8")
print(index)
# Out:
# -1

# %%
text1 = ['1','Neharika']
res = '-'.join(text1)
print(res)
# Out:
# 1-Neharika

# %%
d = {'Geek': 1, 'for': 2, 'Geeks': 3}

# Separator "_" is used to join keys into a single string
res = '_'.join(d.items)

print(res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 d = {'Geek': 1, 'for': 2, 'Geeks': 3}
#       3 # Separator "_" is used to join keys into a single string
# ----> 4 res = '_'.join(d.items)
#       6 print(res)
#
# TypeError: can only join an iterable

# %%
demo = 'Neharika'
print(demo)
demo = 'Keval'
print(demo)
# Out:
# Neharika
# Keval

# %%
text.format()
text.format_map()
text.index()
text.isalnum()
text.isalnum()
text.isalpha()
text.isascii()
text.isdecimal()
text.isdigit()
text.isidentifier()
text.islower()
text.isnumeric()
text.isprintable()
text.isspace()
text.istitle()
text.isupper()

text.ljust()
text.lower()
text.lstrip()
text.maketrans()
text.partition()
text.removeprefix()
text.removesuffix()
text.replace()
text.rfind()
text.index()
text.rjust()
text.rpartition()
text.rsplit()
text.rstrip()
text.split()
text.splitlines()
text.startswith()
text.strip()
text.swapcase()
text.title()
text.translate()
text.upper()
text.zfill()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 text.format()
#       2 text.format_map()
#       3 text.index()
#
# NameError: name 'text' is not defined

# %%
text.center(20,'-')
# Out:
# '------Neharika------'

# %%
text.ljust(20,'-')
# Out:
# 'Neharika------------'
