# %%
#age = True
age = "10"
age = 2.45
print("age" , int(age))
print(type(age))
# Out:
# age 2
# <class 'float'>

# %%
a = ['a','a','a']
print(id(a))
a = ['a','a','j']
print(id(a))
if a is a:
    print("both the variables are same object")
else:
    print("Sorry! both are different")
# Out:
# 2863590622912
# 2863590866176
# both the variables are same object

# %%
x = ['1','2','3','4']
y = ['1','2','3','4']

print(x == y)   #Values of x and y is check
print(x is y)   #Location of x and y is considered
# Out:
# True
# False

# %%
x = ['1','2','3','4']
x = ['1','2','3','4']

print(id(x))
print(id(x))
# Out:
# 2863591291456
# 2863591291456

# %%
#In keyword

list = ['Apple','Banana','Cherry','Mango']
if 'Cherry' in list:
    print('YES')
else:
    print('NO')
# Out:
# YES

# %%
list = ['Apple','Banana','Cherry','Mango']
for i in list:
    print(i)
# Out:
# Apple
# Banana
# Cherry
# Mango
