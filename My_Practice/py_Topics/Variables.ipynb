# %% [markdown]
# # Variables

# %%
X = 10
Y = 20
print(id(X))
print(id(Y))
# Out:
# 140712844461256
# 140712844461576

# %%
x = 10
y = 10
print(id(x))
print(id(y))
# Out:
# 140712844461256
# 140712844461256

# %%
x = 30

# %%
print(x)
# Out:
# 30

# %%
print(id(x))
# Out:
# 140712844461896
