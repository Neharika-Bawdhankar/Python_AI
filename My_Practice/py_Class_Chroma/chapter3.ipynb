# %%
# module

# %%
# build in module
import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
# random
import random

print(random.randint(1,100))
# Out:
# 67

# %%
# thiry party module

# numpy

# %%
# custom module

# %%
# comments
print("hello")  # inline comment
# Out:
# hello

# %%
# multiline comments  ctrl + /

# dfklhdjfhad
# adfkadhfokdjo
# diadhfdjfsao

# %%
'''
hii
hoow are you '''
print("hii")
# Out:
# hii

# %%
# variable

# %%
11 = 10
# Out:
#   Cell In[10], line 1
#     11 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
var 11  =10
# Out:
#   Cell In[29], line 1
#     var 11  =10
#         ^
# SyntaxError: invalid syntax

# %%
var!11 = 10
# Out:
#   Cell In[30], line 1
#     var!11 = 10
#        ^
# SyntaxError: invalid syntax

# %%
var_11 = 10

# %%
name_of_person = "neharika"

# %%
name = "neharika"

# %%
s = 10 # wrong way to declare variable
second_per_min = 60 # right way to declare variable

# %%
# class = 10

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# case sensitivity
name = "neharika"
Name = "bawdhanker"
print(name)
print(Name)
# Out:
# neharika
# bawdhanker

# %%
# multiple assignment
x = y = z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
a,b,c = 10,30,50
print(a)
print(b)
print(c)
# Out:
# 10
# 30
# 50

# %%
# camel case (we should not use it)
AvSigNal = 10
print(AvSigNal)
# Out:
# 10

# %%
# snake case
name_of_person = 10
print(name_of_person)
# Out:
# 10

# %%
# dynamic variable
name_of_var = 10
print(name_of_var)
# Out:
# 10

# %%
# int
# number
num = 10
print(num)
print(type(num))
# Out:
# 10
# <class 'int'>

# %%
# float
float1 = 10.5
print(float1)
print(type(float1))
# Out:
# 10.5
# <class 'float'>

# %%
# string (text)
string = "neharika"
string2 = 'neharika'
string3 = """neharika"""
string4 = '''neharika'''
print(string)
print(type(string))
print(string2)
print(type(string2))
print(string3)
print(type(string3))
print(string4)
print(type(string4))
# Out:
# neharika
# <class 'str'>
# neharika
# <class 'str'>
# neharika
# <class 'str'>
# neharika
# <class 'str'>

# %%
# this is "python" world
print(""" this is "python" world """)
# Out:
#  this is "python" world

# %%
# boolean
bool1 = True
bool2 = False
print(bool1)
print(type(bool1))
print(bool2)
print(type(bool2))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
# list (square brackets)
list1 = [1,2,3,4,5,"neharika",10.5,True]
print(list1)
print(type(list1))
# Out:
# [1, 2, 3, 4, 5, 'neharika', 10.5, True]
# <class 'list'>

# %%
num = "10"
print(num)
# Out:
# 10

# %%
# tuple (parentheses)
tuple1 = (1,2,3,4,5,"neharika",10.5,True)
print(tuple1)
print(type(tuple1))
# Out:
# (1, 2, 3, 4, 5, 'neharika', 10.5, True)
# <class 'tuple'>

# %%
# dictionary (curly brackets)
dict1 = {"name":"neharika","class":12,"Name":"neharika"}
print(dict1)
print(type(dict1))
# Out:
# {'name': 'neharika', 'class': 12, 'Name': 'neharika'}
# <class 'dict'>

# %%
# set (curly brackets)
set1 = {1,1,1,1}  # unorderd
print(set1)
print(type(set1))
# Out:
# {1}
# <class 'set'>

# %%
# None type
none1 = 10
print(none1)
print(type(none1))
# Out:
# 10
# <class 'int'>
