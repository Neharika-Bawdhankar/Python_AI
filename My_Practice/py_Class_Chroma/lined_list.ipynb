# %%
# class Node:
#     def __init__(self,value):
#         self.data = value
#         self.next = None

# %%
# a = Node(1)
# b = Node(2)
# c = Node(3)

# %%
# print(c.data)

# %%
# a.next = b
# b.next = c

# %%
# print(a.next)
# print(b.next)
# print(c.next)

# %%
# int(0x0000017BD7148A10)

# %%
# class Node:
#     def __init__(self,value):
#         self.data = value
#         self.next = None

# %%
# class Linkedlist:
#     def __init__(self):
#         # empty linked list
#         self.head = None
#         # no of nodes in linked list
#         self.n = 0
    
#     def __len__(self):
#         return self.n
    

#     def insert_head(self,value):
#         # new node
#         new_node = Node(value)
#         # connection
#         new_node.next =  self.head

#         # reassign head
#         self.head = new_node
#         # increatment
#         self.n = self.n + 1

# %%
# l = Linkedlist()

# %%
# l.insert_head(1)
# l.insert_head(2)
# l.insert_head(3)
# l.insert_head(4)

# %%
# len(l)

# %%
# print(l)

# %% [markdown]
# # question

# %% [markdown]
# ## Create a singly linked list and insert elements at the beginning, middle, and end.

# %%
from platform import node

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
    
class Linkedlist:
    def __init__(self):
        self.head =None
        
    def insert_beginning(self,data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
    
    def insert_end(self,data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node
    
    def insert_at_postion(self,data,pos):
        new_node = Node(data)
        if pos ==0:
            self.insert_beginning(data)
            return
        temp = self.head
        for _ in range(pos-1):
            if temp is None:
                return
            temp = temp.next
        new_node.next = temp.next
        temp.next =new_node
    
    def display(self):
        temp = self.head
        while temp:
            print(temp.data,end = " -> ")
            temp = temp.next
        print("None")
    
    def search(self,key):
        temp = self.head
        while temp:
            if temp.data == key:
                return True
            temp = temp.next
        return False
    
    def delete_node(self,key):
        temp = self.head
    
        if temp and temp.data == key:
            self.head = temp.next
            temp = None
            return
        
        prev = None
        while temp and temp.data != key:
            prev = temp
            temp = temp.next
        
        if temp is None:
            return
        
        prev.next = temp.next
        temp = None
    

    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev
    
    def middle_list(self):
        slow,fast = self.head, self.head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
        return slow.data

    def remove_dup(self):
        temp = self.head
        while temp and temp.next:
            if temp.data == temp.next.data:
                temp.next = temp.next.next # skip duplicates
            else:
                temp = temp.next
    
    def remove_unsorted(self):
        if not self.head:
            return
        
        seen = set()
        temp = self.head
        seen.add(temp.data)

        while temp.next:
            if temp.next.data in seen:
                temp.next = temp.next.next
            else:
                seen.add(temp.next.data)
                temp = temp.next
# Merge Two Sorted Linked Lists
     
    def mergelist(l1,l2):
        dummy = Linkedlist()
        current = dummy

        while l1 and l2:
            if l1.val < l2.val:
                current.next = l1
                l1 = l1.next 
            else:
                current.next = l2
                l2 = l2.next 
            current =current.next
       
        if l1:
            current.next = l1
        if l2:
            current.next = l2
        
        return dummy.next

# %%
l1 = Linkedlist()

# %%
# l1.insert_beginning(1)
# l1.insert_end(5)
# l1.insert_at_postion(3,1)

# %%
l1.display()
# Out:
# 1 -> 3 -> 5 -> None

# %%
l2 = Linkedlist()

# %%
#l2.insert_beginning(2)
# l2.insert_end(4)
# l2.insert_at_postion(4,1)

# %%
l2.display()
# Out:
# 2 -> 4 -> 6 -> 4 -> None

# %%
l2.remove_unsorted()
l2.display()
# Out:
# 2 -> 4 -> 6 -> None

# %%
merges = Linkedlist(l1.head,l2.head)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[327], line 1
# ----> 1 merges = Linkedlist(l1.head,l2.head)
#
# TypeError: Linkedlist.__init__() takes 1 positional argument but 3 were given

# %%
l2.display()
# Out:
# 30 -> 20 -> 10 -> None

# %%
l2.remove_unsorted()
l2.display()
# Out:
# 30 -> 20 -> 10 -> None

# %%
l1 = Linkedlist()

# %%
l1.insert_beginning(1)
l1.insert_beginning(2)
l1.insert_beginning(3)
l1.insert_beginning(4)
l1.insert_beginning(4)

# %%
l1.display()
# Out:
# 4 -> 4 -> 3 -> 2 -> 1 -> None

# %%
l1.remove_dup()

# %%
l1.display()
# Out:
# 4 -> 3 -> 2 -> 1 -> None

# %%
l1.mergelist(l2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[309], line 1
# ----> 1 l1.mergelist(l2)
#
# Cell In[301], line 122, in Linkedlist.mergelist(l1, l2)
#     119 current = dummy
#     121 while l1 and l2:
# --> 122     if l1.val < l2.val:
#     123         current.next = l1
#     124         l1 = l1.next
#
# AttributeError: 'Linkedlist' object has no attribute 'val'

# %%
# print(l1.search(15))

# %%
# l1.delete_node(5)

# %%
# l1.display()

# %% [markdown]
# ## Write a function to search for an element in a linked list.

# %% [markdown]
# ## Delete a node with a given value from a linked list.

# %% [markdown]
# ## Reverse a linked list using iteration

# %% [markdown]
# ## Find the middle node of a linked list

# %% [markdown]
# ## ## Remove duplicates from a sorted linked list
