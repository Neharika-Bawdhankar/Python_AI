# %%
# built in functions---> print,

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# ## user defined functions

# %%
def greet():
    return "Hello"
    
print(greet())
# Out:
# Hello

# %%
def greet_username(name,age):  # name = paramater
    return f"Hello {name} {age}"
    
print(greet_username("neharika",30))
# print(greet_username("sachin"))  # argument
# Out:
# Hello neharika 30

# %% [markdown]
# ##  Basic Function Syntax
# Problem: Write a function to calculate and return the square of a number.

# %%
def square(num): # paramater -- > num 
    return num ** 2 

print(square(8)) # argument --> 8
# Out:
# 64

# %% [markdown]
# ## 2. Function with Multiple Parameters
# Problem: Create a function that takes two numbers as parameters and returns their sum.

# %%
def add(num1,num2):
    return num1 + num2

print(add(4,6))
# Out:
# 10

# %% [markdown]
# ## 3. Polymorphism in Functions
# Problem: Write a function multiply that multiplies two numbers, but can also accept and multiply strings.

# %%
def multiply(num1,num2):
    return num1 * num2

print(multiply(4,6))
print(multiply('a',6))
print(multiply(5,'b'))
# Out:
# 24
# aaaaaa
# bbbbb

# %% [markdown]
# ## 4. Function Returning Multiple Values
# Problem: Create a function that returns both the area and circumference of a circle given its radius.

# %%
import math

def circle_area(radius):
    area = math.pi * radius ** 2 
    circumference = 2 * math.pi * radius
    return area,circumference

a,c = circle_area(5)
print(f"Area: {a}, Circumference: {c}")
# Out:
# Area: 78.53981633974483, Circumference: 31.41592653589793

# %% [markdown]
# ## 5. Default Parameter Value
# Problem: Write a function that greets a user. If no name is provided, it should greet with a default name.

# %%
def greet(name = "user"):  # user---> default
    print(f"Hello {name}")
    
greet()
print("nehraik")
# Out:
# Hello user
# nehraik

# %% [markdown]
# 4. Function Returning Multiple Values
# 5. Default Parameter Value
# 6. Lambda Function
# 7. Function with *args
# 8. Function with **kwargs
# 9. Generator Function with yield
# 10. Recursive Function
